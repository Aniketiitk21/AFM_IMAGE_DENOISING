# %%
# import cv2
# import numpy as np
# from google.colab import files
# from google.colab.patches import cv2_imshow

# uploaded = files.upload()
# image_filename = list(uploaded.keys())[0]

# def remove_line_noise(image_filename, kernel_size=3, iterations=1):
#     # Read the image
#     img = cv2.imread(image_filename, cv2.IMREAD_GRAYSCALE)

#     # Apply threshold to get a binary image
#     _, binary_image = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

#     # Create a horizontal kernel to remove vertical lines
#     kernel = np.ones((1, kernel_size), np.uint8)

#     # Perform morphological closing to remove line-like noise
#     result_image = cv2.morphologyEx(binary_image, cv2.MORPH_CLOSE, kernel, iterations=iterations)

#     # Display the original and result images
#     cv2_imshow(img)
#     cv2_imshow(result_image)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()

# # Example usage

# remove_line_noise(image_filename, kernel_size=3, iterations=1)

# %%
# import cv2
# import numpy as np
# from google.colab import files
# from google.colab.patches import cv2_imshow

# uploaded = files.upload()
# image_filename = list(uploaded.keys())[0]

# def remove_line_noise(image_filename, kernel_size=3):
#     # Read the image
#     image = cv2.imread(image_filename, cv2.IMREAD_GRAYSCALE)

#     # Apply threshold to get a binary image
#     _, binary_image = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

#     # Create a horizontal kernel for Gaussian blur
#     kernel = np.ones((1, kernel_size), np.float32) / kernel_size

#     # Apply horizontal Gaussian blur
#     result_image = cv2.filter2D(binary_image, -1, kernel)

#     # Display the original and result images
#     cv2_imshow(image)
#     cv2_imshow(result_image)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()

# # Example usage
# remove_line_noise(image_filename, kernel_size=15)

# %%
# import cv2
# import numpy as np
# from google.colab import files
# from google.colab.patches import cv2_imshow

# uploaded = files.upload()
# image_filename = list(uploaded.keys())[0]

# def extract_shapes(image_filename, operation='erode', kernel_size=3, iterations=1):
#     # Read the image
#     image = cv2.imread(image_filename, cv2.IMREAD_GRAYSCALE)

#     # Apply threshold to get a binary image
#     _, binary_image = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

#     # Define a kernel for erosion or dilation
#     kernel = np.ones((kernel_size, kernel_size), np.uint8)

#     # Perform erosion or dilation
#     if operation == 'erode':
#         result_image = cv2.erode(binary_image, kernel, iterations=iterations)
#     elif operation == 'dilate':
#         result_image = cv2.dilate(binary_image, kernel, iterations=iterations)
#     else:
#         raise ValueError("Invalid operation. Use 'erode' or 'dilate'.")

#     # Find contours in the result image
#     contours, _ = cv2.findContours(result_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

#     # Draw contours on the original image
#     result = cv2.drawContours(image.copy(), contours, -1, (0, 255, 0), 2)

#     # Display the original and result images
#     cv2_imshow(image)
#     cv2_imshow(result)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()

# # Example usage
# extract_shapes(image_filename, operation='erode', kernel_size=5, iterations=1)

# %%
# image = cv2.resize(image, None, fx=0.9,fy=0.9)

# gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# #Now convert the grayscale image to binary image
# ret, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# #Now detect the contours
# contours, hierarchy = cv2.findContours(binary, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_NONE)

# #Visualize the data structure
# # print("Length of contours {}".format(len(contours)))
# # print(contours)

# # draw contours on the original image
# image_copy = image.copy()
# image_copy = cv2.drawContours(image_copy, contours, -1, (0, 255, 0), thickness=2, lineType=cv2.LINE_AA)

# #Visualizing the results
# cv2_imshow(gray)
# cv2_imshow(image_copy)
# cv2_imshow(binary)

# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# import os

# for i in os.listdir(os.path.normpath(str(image))):
#     image = cv2.imread(image + i)

# image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
# lower = [np.mean(image[:,:,i] - np.std(image[:,:,i])/3 ) for i in range(3)]
# upper = [250, 250, 250]

# # create NumPy arrays from the boundaries
# lower = np.array(lower, dtype="uint8")
# upper = np.array(upper, dtype="uint8")

# # find the colors within the specified boundaries and apply
# mask = cv2.inRange(image, lower, upper)
# output = cv2.bitwise_and(image, image, mask=mask)

# ret,thresh = cv2.threshold(mask, 40, 255, 0)

# contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

# if len(contours) != 0:
#         # draw in blue the contours that were founded
#         cv2.drawContours(output, contours, -1, 255, 3)

#         # find the biggest countour (c) by the area
#         c = max(contours, key = cv2.contourArea)
#         x,y,w,h = cv2.boundingRect(c)

#         # draw the biggest contour (c) in green
#         cv2.rectangle(output,(x,y),(x+w,y+h),(0,255,0),5)

#         foreground = image[y:y+h,x:x+w]
#         plt.figure(figsize=(20,4))
#         plt.subplot(1,3,1),plt.imshow(image),plt.title("Input",fontdict=font)
#         plt.subplot(1,3,2),plt.imshow(output),plt.title("All Contours",fontdict=font)
#         plt.subplot(1,3,3),plt.imshow(foreground),plt.title("output",fontdict=font)
#         print(foreground.shape)
#         plt.show()

# %%
#1 20/1/24

from skimage import io
from skimage.color import rgb2gray
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import fftpack
import numpy as np

import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

from matplotlib import pyplot as plt

# %%
uploaded = files.upload()
image_filename = list(uploaded.keys())[0]

image = cv2.imread(image_filename)
# Out:
#      <input type="file" id="files-ed7bd5b5-cc38-4507-9e49-feab9ff23735" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed7bd5b5-cc38-4507-9e49-feab9ff23735">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#image = io.imread('img_noise.png', as_gray=True)
image.shape, image.dtype
# Out:
# ((512, 512, 3), dtype('uint8'))

# %%
M,N, O = image.shape
f, ax = plt.subplots(figsize=(5,5))
ax.imshow(image,cmap = "gray")
ax.set_title('Original Noisy Image')
# Out:
# Text(0.5, 1.0, 'Original Noisy Image')

# %%
#Return multidimensional discrete Fourier transform.
F = fftpack.fftn(image)

from numpy import angle
Fp = angle(F)

F_magnitude = np.abs(F)   #absolute value of F

# %%
f, ax = plt.subplots(figsize=(5,5))

ax.imshow(np.log(1 + F_magnitude), cmap='gray',
          extent=(-N // 2, N // 2, -M // 2, M // 2))
ax.set_title('Spectrum magnitude');
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#shifting 0 frequency component
F_magnitude = fftpack.fftshift(F_magnitude)

# %%
f, ax = plt.subplots(figsize=(5,5))

ax.imshow(np.log(1 + F_magnitude), cmap='gray',
          extent=(-N // 2, N // 2, -M // 2, M // 2))
ax.set_title('Spectrum magnitude');
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Set block around center of spectrum to zero
K = 30
F_magnitude[M // 2 - K: M // 2 + K, N // 2 - K: N // 2 + K] = 0

# %%
f, ax = plt.subplots(figsize=(5,5))

ax.imshow(np.log(1 + F_magnitude), cmap='gray',
          extent=(-N // 2, N // 2, -M // 2, M // 2))
ax.set_title('Spectrum magnitude');
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Find all peaks lower than the 98th percentile
peaks = F_magnitude < np.percentile(F_magnitude, 98) #for 98 percentile
peaks1 = F_magnitude < np.percentile(F_magnitude, 100) #for 100 percentile

# Shift the peaks back to align with the original spectrum
peaks = fftpack.ifftshift(peaks) #for 98 percentile
peaks1 = fftpack.ifftshift(peaks1) # for 100 percentile

# %%
# Make a copy of the original (complex) spectrum
F_dim = F.copy()  # for 98 percentile
F_dim1 = F.copy() #for 100 percentile

# Set those peak coefficients to zero
F_dim = F_dim * peaks.astype(int) # for 98 percentile
F_dim1 = F_dim1 * peaks1.astype(int) #for 100 percentile

f, (ax0, ax2)= plt.subplots(1, 2, figsize=(10,10))
ax0.imshow(np.log10(1 + np.abs(F_dim)), cmap='gray')
ax0.set_title('Spectrum after suppression(98 %ile)')

ax2.imshow(np.log10(1 + np.abs(F_dim1)), cmap='gray')
ax2.set_title('Spectrum after suppression(100 %ile)')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Spectrum after suppression(100 %ile)')

# %%
# Do the inverse Fourier transform to get back to an image.
# Since we started with a real image, we only look at the real part of
# the output.

from numpy import exp

image_filtered = np.real(fftpack.ifft2(F_dim)) #for 98 percentile
image_filtered1 = np.real(fftpack.ifft2(F_dim1))  # for 100 percentile

f, (ax1, ax3) = plt.subplots(1, 2, figsize=(10,10))
ax1.imshow(image_filtered, cmap="gray")
ax1.set_title('Reconstructed image(98 %ile)');

ax3.imshow(image_filtered1, cmap="gray")
ax3.set_title('Reconstructed image(100 %ile)');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c19cd36d1b4f> in <cell line: 10>()
#       8 image_filtered1 = np.real(fftpack.ifft2(F_dim1))  # for 100 percentile
#       9
# ---> 10 image_filtered = np.real(ifft2(ifftshift(F * exp(i * Fp))))  # for 98 percentile
#      11 image_filtered1 = np.real(fftpack.ifft2(F_dim1))  # for 100 percentile
#      12
#
# NameError: name 'ifft2' is not defined

# %%
#2 20/1/24

import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

from matplotlib import pyplot as plt

uploaded = files.upload()
image_filename = list(uploaded.keys())[0]

im = cv2.imread(image_filename)
# Out:
#      <input type="file" id="files-3c007d7b-9d3b-4ab9-9aef-188ebeabe39e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c007d7b-9d3b-4ab9-9aef-188ebeabe39e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
plt.figure()
plt.imshow(im, plt.cm.gray)
plt.title('Original image')

from scipy import fftpack
im_fft = fftpack.fft2(im)

# Show the results

from numpy import angle

def plot_spectrum(im_fft):
    from matplotlib.colors import LogNorm
    # A logarithmic colormap
    im_fft_p = angle(im_fft)
    x = np.abs(im_fft)

    plt.imshow(x, norm=LogNorm(vmin=5))
    plt.colorbar()

plt.figure()
plot_spectrum(im_fft)
plt.title('Fourier transform')

############################################################
# Filter in FFT
############################################################

# In the lines following, we'll make a copy of the original spectrum and
# truncate coefficients.

# Define the fraction of coefficients (in each direction) we keep
keep_fraction = 0.1

# Call ff a copy of the original transform. Numpy arrays have a copy
# method for this purpose.
im_fft2 = im_fft.copy()

# Set r and c to be the number of rows and columns of the array.
r, c = im_fft2.shape

# Set to zero all rows with indices between r*keep_fraction and
# r*(1-keep_fraction):
im_fft2[int(r*keep_fraction):int(r*(1-keep_fraction))] = 0

# Similarly with the columns:
im_fft2[:, int(c*keep_fraction):int(c*(1-keep_fraction))] = 0

plt.figure()
plot_spectrum(im_fft2)
plt.title('Filtered Spectrum')


############################################################
# Reconstruct the final image
############################################################

# Reconstruct the denoised image from the filtered spectrum, keep only the
# real part for display.
im_new = fftpack.ifft2(im_fft2).real

plt.figure()
plt.imshow(im_new, plt.cm.gray)
plt.title('Reconstructed Image')

from scipy import ndimage
im_blur = ndimage.gaussian_filter(im, 4)

plt.figure()
plt.imshow(im_blur, plt.cm.gray)
plt.title('Blurred image')

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-f8939eecf586> in <cell line: 22>()
#      20
#      21 plt.figure()
# ---> 22 plot_spectrum(im_fft)
#      23 plt.title('Fourier transform')
#      24
#
# <ipython-input-4-f8939eecf586> in plot_spectrum(im_fft)
#      16     x = np.abs(im_fft)
#      17
# ---> 18     plt.imshow(x, norm=LogNorm(vmin=5))
#      19     plt.colorbar()
#      20
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
# ...

# %%
#3 20/1/24

import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

from matplotlib import pyplot as plt

uploaded = files.upload()
image_filename = list(uploaded.keys())[0]

picture = cv2.imread(image_filename)

# %%
mat = picture[[1, 1]] #/. {r_, g_, b_} :> (0.3r + 0.6g + 0.1b)/1.;
h, w = Dimensions[mat]

# %%
SetOptions[ListDensityPlot, Mesh -> False, AspectRatio -> Automatic];
orig = ListDensityPlot[mat]

# %%
#4 22/01/2024

import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

from skimage.restoration import (denoise_wavelet, estimate_sigma)
from skimage.util import random_noise
from skimage.metrics import peak_signal_noise_ratio
import skimage.io

from matplotlib import pyplot as plt

# %%
uploaded = files.upload()
image_filename = list(uploaded.keys())[0]

img = skimage.io.imread(image_filename)
# Out:
#      <input type="file" id="files-3c4cc11c-45ca-47b0-9d96-7ed4c1ba4a9b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c4cc11c-45ca-47b0-9d96-7ed4c1ba4a9b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Define the Gaussian kernel size and standard deviation
kernel_size = 7
sigma = 3.0

# Apply the Gaussian filter
denoised_img = cv2.GaussianBlur(img, (kernel_size, kernel_size), sigma)

# Display the results
cv2_imshow(img)
cv2_imshow(denoised_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
