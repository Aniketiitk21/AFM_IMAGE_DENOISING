# %% [markdown]
# Multi-Otsu thresholding

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, filters

# Function to process and display the image using Multi-Otsu thresholding
def process_image(image_path):
    # Setting the font size for all plots.
    matplotlib.rcParams['font.size'] = 9

    # Reading the image from the given path.
    image = io.imread(image_path, as_gray=True)

    # Applying multi-Otsu threshold for the default value, generating
    # three classes.
    thresholds = filters.threshold_multiotsu(image)

    # Using the threshold values, we generate the three regions.
    regions = np.digitize(image, bins=thresholds)

    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 3.5))

    # Plotting the original image.
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title('Original')
    ax[0].axis('off')

    # Plotting the histogram and the two thresholds obtained from
    # multi-Otsu.
    ax[1].hist(image.ravel(), bins=255)
    ax[1].set_title('Histogram')
    for thresh in thresholds:
        ax[1].axvline(thresh, color='r')

    # Plotting the Multi Otsu result.
    ax[2].imshow(regions, cmap='jet')
    ax[2].set_title('Multi-Otsu result')
    ax[2].axis('off')

    plt.subplots_adjust()
    plt.show()


image_path = '/content/1_amplitude.jpg'  # Update this path
process_image(image_path)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, filters

# Function to process and display the image using Multi-Otsu thresholding
def process_image(image_path):
    # Setting the font size for all plots.
    matplotlib.rcParams['font.size'] = 9

    # Reading the image from the given path.
    image = io.imread(image_path, as_gray=True)

    # Applying multi-Otsu threshold for the default value, generating
    # three classes.
    thresholds = filters.threshold_multiotsu(image)

    # Using the threshold values, we generate the three regions.
    regions = np.digitize(image, bins=thresholds)

    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 3.5))

    # Plotting the original image.
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title('Original')
    ax[0].axis('off')

    # Plotting the histogram and the two thresholds obtained from
    # multi-Otsu.
    ax[1].hist(image.ravel(), bins=255)
    ax[1].set_title('Histogram')
    for thresh in thresholds:
        ax[1].axvline(thresh, color='r')

    # Plotting the Multi Otsu result.
    ax[2].imshow(regions, cmap='jet')
    ax[2].set_title('Multi-Otsu result')
    ax[2].axis('off')

    plt.subplots_adjust()
    plt.show()


image_path = '/content/11_amplitude.jpg'  # Update this path
process_image(image_path)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, filters

# Function to process and display the image using Multi-Otsu thresholding
def process_image(image_path):
    # Setting the font size for all plots.
    matplotlib.rcParams['font.size'] = 9

    # Reading the image from the given path.
    image = io.imread(image_path, as_gray=True)

    # Applying multi-Otsu threshold for the default value, generating
    # three classes.
    thresholds = filters.threshold_multiotsu(image)

    # Using the threshold values, we generate the three regions.
    regions = np.digitize(image, bins=thresholds)

    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 3.5))

    # Plotting the original image.
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title('Original')
    ax[0].axis('off')

    # Plotting the histogram and the two thresholds obtained from
    # multi-Otsu.
    ax[1].hist(image.ravel(), bins=255)
    ax[1].set_title('Histogram')
    for thresh in thresholds:
        ax[1].axvline(thresh, color='r')

    # Plotting the Multi Otsu result.
    ax[2].imshow(regions, cmap='jet')
    ax[2].set_title('Multi-Otsu result')
    ax[2].axis('off')

    plt.subplots_adjust()
    plt.show()


image_path = '/content/14_amplitude.jpg'  # Update this path
process_image(image_path)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, filters

# Function to process and display the image using Multi-Otsu thresholding
def process_image(image_path):
    # Setting the font size for all plots.
    matplotlib.rcParams['font.size'] = 9

    # Reading the image from the given path.
    image = io.imread(image_path, as_gray=True)

    # Applying multi-Otsu threshold for the default value, generating
    # three classes.
    thresholds = filters.threshold_multiotsu(image)

    # Using the threshold values, we generate the three regions.
    regions = np.digitize(image, bins=thresholds)

    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 3.5))

    # Plotting the original image.
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title('Original')
    ax[0].axis('off')

    # Plotting the histogram and the two thresholds obtained from
    # multi-Otsu.
    ax[1].hist(image.ravel(), bins=255)
    ax[1].set_title('Histogram')
    for thresh in thresholds:
        ax[1].axvline(thresh, color='r')

    # Plotting the Multi Otsu result.
    ax[2].imshow(regions, cmap='jet')
    ax[2].set_title('Multi-Otsu result')
    ax[2].axis('off')

    plt.subplots_adjust()
    plt.show()


image_path = '/content/16_amplitude.jpg'  # Update this path
process_image(image_path)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, filters

# Function to process and display the image using Multi-Otsu thresholding
def process_image(image_path):
    # Setting the font size for all plots.
    matplotlib.rcParams['font.size'] = 9

    # Reading the image from the given path.
    image = io.imread(image_path, as_gray=True)

    # Applying multi-Otsu threshold for the default value, generating
    # three classes.
    thresholds = filters.threshold_multiotsu(image)

    # Using the threshold values, we generate the three regions.
    regions = np.digitize(image, bins=thresholds)

    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 3.5))

    # Plotting the original image.
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title('Original')
    ax[0].axis('off')

    # Plotting the histogram and the two thresholds obtained from
    # multi-Otsu.
    ax[1].hist(image.ravel(), bins=255)
    ax[1].set_title('Histogram')
    for thresh in thresholds:
        ax[1].axvline(thresh, color='r')

    # Plotting the Multi Otsu result.
    ax[2].imshow(regions, cmap='jet')
    ax[2].set_title('Multi-Otsu result')
    ax[2].axis('off')

    plt.subplots_adjust()
    plt.show()


image_path = '/content/10_amplitude.jpg'  # Update this path
process_image(image_path)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, filters

# Function to process and display the image using Multi-Otsu thresholding
def process_image(image_path):
    # Setting the font size for all plots.
    matplotlib.rcParams['font.size'] = 9

    # Reading the image from the given path.
    image = io.imread(image_path, as_gray=True)

    # Applying multi-Otsu threshold for the default value, generating
    # three classes.
    thresholds = filters.threshold_multiotsu(image)

    # Using the threshold values, we generate the three regions.
    regions = np.digitize(image, bins=thresholds)

    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 3.5))

    # Plotting the original image.
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title('Original')
    ax[0].axis('off')

    # Plotting the histogram and the two thresholds obtained from
    # multi-Otsu.
    ax[1].hist(image.ravel(), bins=255)
    ax[1].set_title('Histogram')
    for thresh in thresholds:
        ax[1].axvline(thresh, color='r')

    # Plotting the Multi Otsu result.
    ax[2].imshow(regions, cmap='jet')
    ax[2].set_title('Multi-Otsu result')
    ax[2].axis('off')

    plt.subplots_adjust()
    plt.show()


image_path = '/content/11_phase.jpg'  # Update this path
process_image(image_path)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, filters

# Function to process and display the image using Multi-Otsu thresholding
def process_image(image_path):
    # Setting the font size for all plots.
    matplotlib.rcParams['font.size'] = 9

    # Reading the image from the given path.
    image = io.imread(image_path, as_gray=True)

    # Applying multi-Otsu threshold for the default value, generating
    # three classes.
    thresholds = filters.threshold_multiotsu(image)

    # Using the threshold values, we generate the three regions.
    regions = np.digitize(image, bins=thresholds)

    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 3.5))

    # Plotting the original image.
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title('Original')
    ax[0].axis('off')

    # Plotting the histogram and the two thresholds obtained from
    # multi-Otsu.
    ax[1].hist(image.ravel(), bins=255)
    ax[1].set_title('Histogram')
    for thresh in thresholds:
        ax[1].axvline(thresh, color='r')

    # Plotting the Multi Otsu result.
    ax[2].imshow(regions, cmap='jet')
    ax[2].set_title('Multi-Otsu result')
    ax[2].axis('off')

    plt.subplots_adjust()
    plt.show()


image_path = '/content/16_phase.jpg'  # Update this path
process_image(image_path)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, filters

# Function to process and display the image using Multi-Otsu thresholding
def process_image(image_path):
    # Setting the font size for all plots.
    matplotlib.rcParams['font.size'] = 9

    # Reading the image from the given path.
    image = io.imread(image_path, as_gray=True)

    # Applying multi-Otsu threshold for the default value, generating
    # three classes.
    thresholds = filters.threshold_multiotsu(image)

    # Using the threshold values, we generate the three regions.
    regions = np.digitize(image, bins=thresholds)

    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 3.5))

    # Plotting the original image.
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title('Original')
    ax[0].axis('off')

    # Plotting the histogram and the two thresholds obtained from
    # multi-Otsu.
    ax[1].hist(image.ravel(), bins=255)
    ax[1].set_title('Histogram')
    for thresh in thresholds:
        ax[1].axvline(thresh, color='r')

    # Plotting the Multi Otsu result.
    ax[2].imshow(regions, cmap='jet')
    ax[2].set_title('Multi-Otsu result')
    ax[2].axis('off')

    plt.subplots_adjust()
    plt.show()


image_path = '/content/14_phase.jpg'  # Update this path
process_image(image_path)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, filters

# Function to process and display the image using Multi-Otsu thresholding
def process_image(image_path):
    # Setting the font size for all plots.
    matplotlib.rcParams['font.size'] = 9

    # Reading the image from the given path.
    image = io.imread(image_path, as_gray=True)

    # Applying multi-Otsu threshold for the default value, generating
    # three classes.
    thresholds = filters.threshold_multiotsu(image)

    # Using the threshold values, we generate the three regions.
    regions = np.digitize(image, bins=thresholds)

    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 3.5))

    # Plotting the original image.
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title('Original')
    ax[0].axis('off')

    # Plotting the histogram and the two thresholds obtained from
    # multi-Otsu.
    ax[1].hist(image.ravel(), bins=255)
    ax[1].set_title('Histogram')
    for thresh in thresholds:
        ax[1].axvline(thresh, color='r')

    # Plotting the Multi Otsu result.
    ax[2].imshow(regions, cmap='jet')
    ax[2].set_title('Multi-Otsu result')
    ax[2].axis('off')

    plt.subplots_adjust()
    plt.show()


image_path = '/content/10_phase.jpg'  # Update this path
process_image(image_path)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, filters

# Function to process and display the image using Multi-Otsu thresholding
def process_image(image_path):
    # Setting the font size for all plots.
    matplotlib.rcParams['font.size'] = 9

    # Reading the image from the given path.
    image = io.imread(image_path, as_gray=True)

    # Applying multi-Otsu threshold for the default value, generating
    # three classes.
    thresholds = filters.threshold_multiotsu(image)

    # Using the threshold values, we generate the three regions.
    regions = np.digitize(image, bins=thresholds)

    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 3.5))

    # Plotting the original image.
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title('Original')
    ax[0].axis('off')

    # Plotting the histogram and the two thresholds obtained from
    # multi-Otsu.
    ax[1].hist(image.ravel(), bins=255)
    ax[1].set_title('Histogram')
    for thresh in thresholds:
        ax[1].axvline(thresh, color='r')

    # Plotting the Multi Otsu result.
    ax[2].imshow(regions, cmap='jet')
    ax[2].set_title('Multi-Otsu result')
    ax[2].axis('off')

    plt.subplots_adjust()
    plt.show()


image_path = '/content/1_phase.jpg'  # Update this path
process_image(image_path)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, filters

# Function to process and display the image using Multi-Otsu thresholding
def process_image(image_path):
    # Setting the font size for all plots.
    matplotlib.rcParams['font.size'] = 9

    # Reading the image from the given path.
    image = io.imread(image_path, as_gray=True)

    # Applying multi-Otsu threshold for the default value, generating
    # three classes.
    thresholds = filters.threshold_multiotsu(image)

    # Using the threshold values, we generate the three regions.
    regions = np.digitize(image, bins=thresholds)

    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 3.5))

    # Plotting the original image.
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title('Original')
    ax[0].axis('off')

    # Plotting the histogram and the two thresholds obtained from
    # multi-Otsu.
    ax[1].hist(image.ravel(), bins=255)
    ax[1].set_title('Histogram')
    for thresh in thresholds:
        ax[1].axvline(thresh, color='r')

    # Plotting the Multi Otsu result.
    ax[2].imshow(regions, cmap='jet')
    ax[2].set_title('Multi-Otsu result')
    ax[2].axis('off')

    plt.subplots_adjust()
    plt.show()


image_path = '/content/2_phase.jpg'  # Update this path
process_image(image_path)
